# %% [markdown]
# # Training

# %%
# !nvidia-smi
# Out:
# Sat May 16 14:31:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/b3/Data/football-players-detection
# Out:
# /content/drive/MyDrive/b3/Data/football-players-detection

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# ...

# %%
# !python scripts/train_football_detector.py \
  --model yolov8n.pt \
  --data football-players-detection.v1i.yolov8/data.yaml \
  --epochs 50 \
  --batch 2 \
  --imgsz 1920 \
  --device cuda \
  --run-name colab_v1_50e_1920_b2
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # Exporting

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/b3/Data/football-players-detection
# Out:
# /content/drive/MyDrive/b3/Data/football-players-detection

# %%
# !find . -name "best.pt" -o -name "last.pt" -o -name "football_yolov8_best.pt"
# Out:
# ./runs/detect/runs/detect/colab_v1_50e_1920_b2/weights/best.pt
# ./runs/detect/runs/detect/colab_v1_50e_1920_b2/weights/last.pt

# %%
from google.colab import files
files.download("runs/detect/runs/detect/colab_v1_50e_1920_b2/weights/best.pt")
